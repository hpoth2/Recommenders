# %%
import pandas as pd
import numpy as np

# %%
M = pd.read_csv('H:\Linux\MovieReviews.csv', index_col='Name')

# %%
M
# Out:
#                              American Sniper  \
# Name
# Mike                                     NaN
# HJ SONG                                  NaN
# Ryan Hansen                              NaN
# Olumuyiwa Durojaiye                      NaN
# Charlie                                  NaN
# Sina Tuy                                 NaN
# Pavithra Shetty                          NaN
# Sara Collins                             NaN
# Jonathan Doll                            NaN
# saikiran reddy                             3
# Aishwarya reddy                          NaN
# Brant Mullinix                           NaN
# Sai Sampath                              NaN
# Suyendra                                 NaN
# Sai Yallapragada                           5
# Akhilesh                                 NaN
# Sundar Prasad                            NaN
# Evan Piercy                                4
# Jessica Fong                             NaN
# Onsiri Tapsarn                             3
# ...

# %%
def pearson(s1, s2):
    """Take two pd.Series objects and return a pearson correlation."""
    s1_c = s1 - s1.mean()
    s2_c = s2 - s2.mean()
    return np.sum(s1_c * s2_c) / np.sqrt(np.sum(s1_c ** 2) * np.sum(s2_c ** 2))

# %%
def get_recs(movie_name, M, num):

    import numpy as np
    reviews = []
    for title in M.columns:
        if title == movie_name:
            continue
        cor = pearson(M[movie_name], M[title])
        if np.isnan(cor):
            continue
        else:
            reviews.append((title, cor))
    
    reviews.sort(key=lambda tup: tup[1], reverse=True)
    return reviews[:num]

# %%
recs = get_recs('The Fault in Our Stars', M, 10)

# %%
# top most movie similar to The Fault in Our Stars
recs[:1]
# Out:
# [('Malificent', 0.4290694760646056)]

# %%
# See all index names
M.index.values
# Out:
# array(['Mike', 'HJ SONG', 'Ryan Hansen', 'Olumuyiwa Durojaiye', 'Charlie',
#        'Sina Tuy', 'Pavithra Shetty', 'Sara Collins', 'Jonathan Doll',
#        'saikiran reddy', 'Aishwarya reddy', 'Brant Mullinix',
#        'Sai Sampath', 'Suyendra', 'Sai Yallapragada', 'Akhilesh',
#        'Sundar Prasad', 'Evan Piercy', 'Jessica Fong', 'Onsiri Tapsarn',
#        'Anirudh Thota', 'Greg Werner', 'Violeta Lee Fay',
#        'Aditya Dharmasagar', 'Manideep Maddipatla', 'Maheshwar Reddy',
#        'siddanth sudarshan', 'anurag', 'Ahmed Muheebuddin', 'azam',
#        'Aswini kumar', 'M A Nissar', 'Yinka Adeyemo', 'Thomas Podlipni',
#        'Bradley Brubaker', 'Harish Kallianpur', 'J A Barnes',
#        'Jared Knowles', 'veerendra battula', 'Trudy Kline',
#        'Rajesh Kinkirla', 'Syed Farzan', 'Syed Abbas Hussaini',
#        'Arun Vedere', 'Venkatesh Komma', 'Graham Bullard',
#        'solomon choppara', 'Susan Huang', 'Aarti Jaiswal',
# ...

# %%
# Delete null indexes rows
M = M[pd.notnull(M.index)]

# %%
M.index.values
# Out:
# array(['Mike', 'HJ SONG', 'Ryan Hansen', 'Olumuyiwa Durojaiye', 'Charlie',
#        'Sina Tuy', 'Pavithra Shetty', 'Sara Collins', 'Jonathan Doll',
#        'saikiran reddy', 'Aishwarya reddy', 'Brant Mullinix',
#        'Sai Sampath', 'Suyendra', 'Sai Yallapragada', 'Akhilesh',
#        'Sundar Prasad', 'Evan Piercy', 'Jessica Fong', 'Onsiri Tapsarn',
#        'Anirudh Thota', 'Greg Werner', 'Violeta Lee Fay',
#        'Aditya Dharmasagar', 'Manideep Maddipatla', 'Maheshwar Reddy',
#        'siddanth sudarshan', 'anurag', 'Ahmed Muheebuddin', 'azam',
#        'Aswini kumar', 'M A Nissar', 'Yinka Adeyemo', 'Thomas Podlipni',
#        'Bradley Brubaker', 'Harish Kallianpur', 'J A Barnes',
#        'Jared Knowles', 'veerendra battula', 'Trudy Kline',
#        'Rajesh Kinkirla', 'Syed Farzan', 'Syed Abbas Hussaini',
#        'Arun Vedere', 'Venkatesh Komma', 'Graham Bullard',
#        'solomon choppara', 'Susan Huang', 'Aarti Jaiswal',
# ...

# %%
# get the top rated movie for each classmate
import numpy as np
watchlist = []
for name in M.index.values:
        my_ratings = M.ix[name].dropna()
        my_ratings.sort(ascending=False)
        movie = my_ratings.index[0]
        watchlist.append(movie)
# Out:
# C:\Users\doranala493\Anaconda2\lib\site-packages\ipykernel\__main__.py:6: FutureWarning: sort is deprecated, use sort_values(inplace=True) for for INPLACE sorting

# %%
# Show unique values
np.unique(watchlist)
# Out:
# array(['300: Rise of an Empire', 'American Sniper', 'Big Hero 6',
#        'Divergent', 'Godzilla', 'Gone Girl', 'Guardians of the Galaxy',
#        'How to Train your Dragon 2', 'Interstellar', 'Malificent',
#        'The Fault in Our Stars', 'The Hobbit', 'Transformers', 'Unbroken'],
#       dtype='|S26')
